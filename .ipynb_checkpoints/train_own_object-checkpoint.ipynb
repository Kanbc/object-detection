# %% [markdown]
# # Step
# 1. prepare dataset
# 2. train model
# 3. predict the object

# %% [markdown]
# cr :
# 1. https://towardsdatascience.com/yolov2-object-detection-using-darkflow-83db6aa5cf5f
# 2. https://towardsdatascience.com/yolov2-to-detect-your-own-objects-soccer-ball-using-darkflow-a4f98d5ce5bf

# %% [markdown]
# --------------------

# %% [markdown]
# ## 1 Prepare Dataset (LabelImg)
# - install ตามในนี้ https://github.com/tzutalin/labelImg
# ### Steps
# 1. Build and launch using the instructions above.
# 2. Click 'Change default saved annotation folder' in Menu/File
# 3. Click 'Open Dir'
# 4. Click 'Create RectBox'
# 5. Click and release left mouse to select a region to annotate the rect box
# 6. You can use right mouse to drag the rect box to copy or move it

# %% [markdown]
# ..... Label รูปไปเรื่อยๆจนครบ

# %% [markdown]
# ## 2 Train Model

# %% [markdown]
# เอา weights เดิม กับ config ใหม่ที่เราทำไว้มา train เพิ่มจะได้

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from darkflow.net.build import TFNet
import cv2

# %%
options = {"model": "cfg/tiny-yolo-voc-2c.cfg", 
           "load": "bin/tiny-yolo-voc.weights",
           "batch": 8,
           "epoch": 100,
           "gpu": 1.0,
           "train": True,
           "annotation": "./train/Annotations/",
           "dataset": "./train/Images/"}

# %% [markdown]
# Defining Model Options & Build the Model

# %%
tfnet = TFNet(options)
# Out:
# Parsing ./cfg/tiny-yolo-voc.cfg
# Parsing cfg/tiny-yolo-voc-2c.cfg
# Loading bin/tiny-yolo-voc.weights ...
# Successfully identified 63471556 bytes
# Finished in 0.7484719753265381s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | maxp 2x2p0_1                     | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 35)
# -------+--------+----------------------------------+---------------
# GPU mode with 1.0 usage
# cfg/tiny-yolo-voc-2c.cfg loss hyper-parameters:
# 	H       = 13
# 	W       = 13
# 	box     = 5
# 	classes = 2
# 	scales  = [1.0, 5.0, 1.0, 1.0]
# Building cfg/tiny-yolo-voc-2c.cfg loss
# INFO:tensorflow:Summary name cfg/tiny-yolo-voc-2c.cfg loss is illegal; using cfg/tiny-yolo-voc-2c.cfg_loss instead.
# Building cfg/tiny-yolo-voc-2c.cfg train op
# Finished in 8.510539054870605s

# %% [markdown]
# Training the Model

# %%
tfnet.train()
# Out:
# cfg/tiny-yolo-voc-2c.cfg parsing ./train/Annotations/
# Parsing for ['idcard', 'person']
# [====================>]100%  1.xml
# Statistics:
# person: 8
# idcard: 13
# Dataset size: 13
# Dataset of 13 instance(s)
# Training statistics:
# 	Learning rate : 1e-05
# 	Batch size    : 8
# 	Epoch number  : 100
# 	Backup every  : 2000
# step 1 - loss 66.844482421875 - moving ave loss 66.844482421875
# Finish 1 epoch(es)
# step 2 - loss 65.58966064453125 - moving ave loss 66.71900024414063
# Finish 2 epoch(es)
# step 3 - loss 65.67852783203125 - moving ave loss 66.6149530029297
# Finish 3 epoch(es)
# step 4 - loss 65.06048583984375 - moving ave loss 66.4595062866211
# Finish 4 epoch(es)
# step 5 - loss 64.86000061035156 - moving ave loss 66.29955571899416
# Finish 5 epoch(es)
# step 6 - loss 64.25653076171875 - moving ave loss 66.09525322326661
# Finish 6 epoch(es)
# step 7 - loss 63.799964904785156 - moving ave loss 65.86572439141847
# Finish 7 epoch(es)
# step 8 - loss 63.893436431884766 - moving ave loss 65.6684955954651
# Finish 8 epoch(es)
# step 9 - loss 63.20991134643555 - moving ave loss 65.42263717056214
# Finish 9 epoch(es)
# step 10 - loss 62.92412567138672 - moving ave loss 65.1727860206446
# Finish 10 epoch(es)
# step 11 - loss 62.57591247558594 - moving ave loss 64.91309866613872
# Finish 11 epoch(es)
# step 12 - loss 62.379119873046875 - moving ave loss 64.65970078682955
# Finish 12 epoch(es)
# step 13 - loss 61.77533721923828 - moving ave loss 64.37126443007043
# Finish 13 epoch(es)
# step 14 - loss 61.29160690307617 - moving ave loss 64.06329867737101
# Finish 14 epoch(es)
# step 15 - loss 61.350677490234375 - moving ave loss 63.792036558657344
# Finish 15 epoch(es)
# step 16 - loss 60.618896484375 - moving ave loss 63.474722551229114
# Finish 16 epoch(es)
# step 17 - loss 60.31385040283203 - moving ave loss 63.15863533638941
# Finish 17 epoch(es)
# step 18 - loss 60.08515167236328 - moving ave loss 62.8512869699868
# Finish 18 epoch(es)
# step 19 - loss 59.260498046875 - moving ave loss 62.49220807767563
# Finish 19 epoch(es)
# step 20 - loss 59.19105529785156 - moving ave loss 62.16209279969322
# Finish 20 epoch(es)
# step 21 - loss 58.73653793334961 - moving ave loss 61.81953731305886
# Finish 21 epoch(es)
# step 22 - loss 58.415687561035156 - moving ave loss 61.47915233785649
# Finish 22 epoch(es)
# step 23 - loss 58.29431915283203 - moving ave loss 61.160669019354046
# Finish 23 epoch(es)
# step 24 - loss 58.417537689208984 - moving ave loss 60.886355886339544
# Finish 24 epoch(es)
# step 25 - loss 57.29666519165039 - moving ave loss 60.52738681687063
# Finish 25 epoch(es)
# step 26 - loss 56.91702651977539 - moving ave loss 60.16635078716111
# Finish 26 epoch(es)
# step 27 - loss 56.355712890625 - moving ave loss 59.7852869975075
# Finish 27 epoch(es)
# step 28 - loss 56.43573760986328 - moving ave loss 59.45033205874308
# Finish 28 epoch(es)
# step 29 - loss 55.50541687011719 - moving ave loss 59.05584053988049
# Finish 29 epoch(es)
# step 30 - loss 55.53125762939453 - moving ave loss 58.70338224883189
# Finish 30 epoch(es)
# step 31 - loss 54.98078155517578 - moving ave loss 58.33112217946628
# Finish 31 epoch(es)
# step 32 - loss 54.67232894897461 - moving ave loss 57.96524285641711
# Finish 32 epoch(es)
# step 33 - loss 54.14482116699219 - moving ave loss 57.58320068747462
# Finish 33 epoch(es)
# step 34 - loss 54.20024108886719 - moving ave loss 57.244904727613886
# Finish 34 epoch(es)
# step 35 - loss 53.5644416809082 - moving ave loss 56.876858422943315
# Finish 35 epoch(es)
# step 36 - loss 54.20198440551758 - moving ave loss 56.609371021200744
# Finish 36 epoch(es)
# step 37 - loss 53.24867630004883 - moving ave loss 56.27330154908555
# Finish 37 epoch(es)
# step 38 - loss 52.361366271972656 - moving ave loss 55.882108021374265
# Finish 38 epoch(es)
# step 39 - loss 51.78253173828125 - moving ave loss 55.472150393064965
# Finish 39 epoch(es)
# step 40 - loss 51.660736083984375 - moving ave loss 55.091008962156906
# Finish 40 epoch(es)
# step 41 - loss 51.40336990356445 - moving ave loss 54.72224505629766
# Finish 41 epoch(es)
# step 42 - loss 50.72102737426758 - moving ave loss 54.32212328809465
# Finish 42 epoch(es)
# step 43 - loss 50.819217681884766 - moving ave loss 53.97183272747367
# Finish 43 epoch(es)
# step 44 - loss 50.68304443359375 - moving ave loss 53.64295389808568
# Finish 44 epoch(es)
# step 45 - loss 50.08973693847656 - moving ave loss 53.28763220212477
# Finish 45 epoch(es)
# step 46 - loss 49.45346450805664 - moving ave loss 52.90421543271796
# Finish 46 epoch(es)
# step 47 - loss 49.5228271484375 - moving ave loss 52.56607660428992
# Finish 47 epoch(es)
# step 48 - loss 48.961307525634766 - moving ave loss 52.20559969642441
# Finish 48 epoch(es)
# step 49 - loss 48.05298614501953 - moving ave loss 51.79033834128393
# Finish 49 epoch(es)
# step 50 - loss 48.469200134277344 - moving ave loss 51.45822452058327
# Finish 50 epoch(es)
# step 51 - loss 47.747650146484375 - moving ave loss 51.087167083173384
# Finish 51 epoch(es)
# step 52 - loss 47.544647216796875 - moving ave loss 50.732915096535734
# Finish 52 epoch(es)
# step 53 - loss 47.149688720703125 - moving ave loss 50.37459245895248
# Finish 53 epoch(es)
# step 54 - loss 46.491416931152344 - moving ave loss 49.98627490617246
# Finish 54 epoch(es)
# step 55 - loss 46.828983306884766 - moving ave loss 49.67054574624369
# Finish 55 epoch(es)
# step 56 - loss 45.89845275878906 - moving ave loss 49.29333644749823
# Finish 56 epoch(es)
# step 57 - loss 45.83092498779297 - moving ave loss 48.947095301527696
# Finish 57 epoch(es)
# step 58 - loss 45.45782470703125 - moving ave loss 48.59816824207805
# Finish 58 epoch(es)
# step 59 - loss 45.110313415527344 - moving ave loss 48.249382759422986
# Finish 59 epoch(es)
# step 60 - loss 44.81984329223633 - moving ave loss 47.90642881270433
# Finish 60 epoch(es)
# step 61 - loss 44.424156188964844 - moving ave loss 47.55820155033038
# Finish 61 epoch(es)
# step 62 - loss 44.17667007446289 - moving ave loss 47.220048402743636
# Finish 62 epoch(es)
# step 63 - loss 44.001163482666016 - moving ave loss 46.89815991073587
# Finish 63 epoch(es)
# step 64 - loss 43.8638801574707 - moving ave loss 46.59473193540936
# Finish 64 epoch(es)
# step 65 - loss 43.56188201904297 - moving ave loss 46.29144694377272
# Finish 65 epoch(es)
# step 66 - loss 43.46623229980469 - moving ave loss 46.00892547937591
# Finish 66 epoch(es)
# step 67 - loss 42.33678436279297 - moving ave loss 45.64171136771762
# Finish 67 epoch(es)
# step 68 - loss 42.34184646606445 - moving ave loss 45.3117248775523
# Finish 68 epoch(es)
# step 69 - loss 41.53380584716797 - moving ave loss 44.93393297451387
# Finish 69 epoch(es)
# step 70 - loss 41.698707580566406 - moving ave loss 44.61041043511913
# Finish 70 epoch(es)
# step 71 - loss 41.92938995361328 - moving ave loss 44.34230838696855
# Finish 71 epoch(es)
# step 72 - loss 41.5667724609375 - moving ave loss 44.06475479436544
# Finish 72 epoch(es)
# step 73 - loss 40.413944244384766 - moving ave loss 43.69967373936738
# Finish 73 epoch(es)
# step 74 - loss 40.64143371582031 - moving ave loss 43.39384973701267
# Finish 74 epoch(es)
# step 75 - loss 40.17375183105469 - moving ave loss 43.07183994641688
# Finish 75 epoch(es)
# step 76 - loss 40.156585693359375 - moving ave loss 42.78031452111113
# Finish 76 epoch(es)
# step 77 - loss 39.37248992919922 - moving ave loss 42.439532061919934
# Finish 77 epoch(es)
# step 78 - loss 39.936553955078125 - moving ave loss 42.18923425123576
# Finish 78 epoch(es)
# step 79 - loss 39.3988151550293 - moving ave loss 41.910192341615115
# Finish 79 epoch(es)
# step 80 - loss 39.095848083496094 - moving ave loss 41.62875791580321
# Finish 80 epoch(es)
# step 81 - loss 38.51707458496094 - moving ave loss 41.31758958271899
# Finish 81 epoch(es)
# step 82 - loss 37.482879638671875 - moving ave loss 40.93411858831428
# Finish 82 epoch(es)
# step 83 - loss 38.116302490234375 - moving ave loss 40.65233697850629
# Finish 83 epoch(es)
# step 84 - loss 39.14867401123047 - moving ave loss 40.50197068177871
# Finish 84 epoch(es)
# step 85 - loss 37.725341796875 - moving ave loss 40.22430779328833
# Finish 85 epoch(es)
# step 86 - loss 37.558631896972656 - moving ave loss 39.95774020365677
# Finish 86 epoch(es)
# step 87 - loss 37.57915496826172 - moving ave loss 39.71988168011727
# Finish 87 epoch(es)
# step 88 - loss 37.01523208618164 - moving ave loss 39.449416720723704
# Finish 88 epoch(es)
# step 89 - loss 36.31482696533203 - moving ave loss 39.13595774518454
# Finish 89 epoch(es)
# step 90 - loss 36.49298095703125 - moving ave loss 38.87166006636921
# Finish 90 epoch(es)
# step 91 - loss 35.9496955871582 - moving ave loss 38.57946361844811
# Finish 91 epoch(es)
# step 92 - loss 35.34040451049805 - moving ave loss 38.255557707653104
# Finish 92 epoch(es)
# step 93 - loss 34.929649353027344 - moving ave loss 37.92296687219053
# Finish 93 epoch(es)
# step 94 - loss 34.62168884277344 - moving ave loss 37.592839069248825
# Finish 94 epoch(es)
# step 95 - loss 35.1954460144043 - moving ave loss 37.35309976376438
# Finish 95 epoch(es)
# step 96 - loss 34.43058776855469 - moving ave loss 37.06084856424341
# Finish 96 epoch(es)
# step 97 - loss 33.87556838989258 - moving ave loss 36.74232054680832
# Finish 97 epoch(es)
# step 98 - loss 34.620086669921875 - moving ave loss 36.530097159119684
# Finish 98 epoch(es)
# step 99 - loss 34.55948257446289 - moving ave loss 36.333035700654
# Finish 99 epoch(es)
# step 100 - loss 33.76082992553711 - moving ave loss 36.07581512314231
# Finish 100 epoch(es)
# Checkpoint at step 100

# %%
tfnet.savepb()

# %% [markdown]
# #### Loading from the Latest Checkpoint
# This cell shows how to load custom trained model from the checkpoint. It will easy your work.
#
# 1. model: the model configuration that you used (*.cfg)
#
# 2. load: set -1. In this way, the latest checkpoint will be loaded.

# %%
options2 = {"model": "cfg/tiny-yolo-voc-2c.cfg",
           "load": -1,
           "gpu": 1.0}

# %%
tfnet2 = TFNet(options2)
# Out:
# Parsing cfg/tiny-yolo-voc-2c.cfg
# Loading None ...
# Finished in 9.512901306152344e-05s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 256)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | maxp 2x2p0_1                     | (?, 13, 13, 512)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 35)
# -------+--------+----------------------------------+---------------
# GPU mode with 1.0 usage
# Loading from ./ckpt/tiny-yolo-voc-2c-100
# INFO:tensorflow:Restoring parameters from ./ckpt/tiny-yolo-voc-2c-100
# Finished in 4.760125160217285s

# %%
tfnet2.load_from_ckpt()
# Out:
# Loading from ./ckpt/tiny-yolo-voc-2c-100
# INFO:tensorflow:Restoring parameters from ./ckpt/tiny-yolo-voc-2c-100

# %% [markdown]
# ## 3 Predict the object

# %%
import pprint as pp

original_img = cv2.imread("train/Images/10.jpg")
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
results = tfnet2.return_predict(original_img)
print(results)
# Out:
# [{'label': 'idcard', 'confidence': 0.51310223, 'topleft': {'x': 218, 'y': 509}, 'bottomright': {'x': 503, 'y': 744}}, {'label': 'person', 'confidence': 0.52606755, 'topleft': {'x': 16, 'y': 0}, 'bottomright': {'x': 698, 'y': 959}}]

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax.imshow(original_img)

# %%
def boxing(original_img , predictions):
    newImage = np.copy(original_img)

    for result in predictions:
        top_x = result['topleft']['x']
        top_y = result['topleft']['y']

        btm_x = result['bottomright']['x']
        btm_y = result['bottomright']['y']

        confidence = result['confidence']
        label = result['label'] + " " + str(round(confidence, 3))
        
        if confidence > 0.3:
            newImage = cv2.rectangle(newImage, (top_x, top_y), (btm_x, btm_y), (255,0,0), 3)
            newImage = cv2.putText(newImage, label, (top_x, top_y-5), cv2.FONT_HERSHEY_COMPLEX_SMALL , 0.8, (0, 230, 0), 1, cv2.LINE_AA)
        
    return newImage

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.imshow(boxing(original_img, results))

# %%
from math import ceil

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

for i in range(6):
    original_img = cv2.imread("train/Images/" + str(i+5) + ".jpg")
    original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
    results = tfnet2.return_predict(original_img)
    
    ax[ceil(i/3)-1, i%3].imshow(boxing(original_img, results))

# %% [markdown]
# ## Predicting on a Video

# %%
cap = cv2.VideoCapture('./sample_video/IMG_2889.mp4')
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)   
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT) 

fourcc = cv2.VideoWriter_fourcc(*'DIVX')
out = cv2.VideoWriter('./sample_video/output.avi',fourcc, 20.0, (int(width), int(height)))

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if ret == True:
        frame = np.asarray(frame)      
        results = tfnet2.return_predict(frame)
        
        new_frame = boxing(frame, results)

        # Display the resulting frame
        out.write(new_frame)
        cv2.imshow('frame', new_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# When everything done, release the capture
cap.release()
out.release()
cv2.destroyAllWindows()
